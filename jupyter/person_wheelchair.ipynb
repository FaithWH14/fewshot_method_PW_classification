# %% [markdown]
# # Domain-specific-Fewshot-Learning using Person/Wheelchair Datasets
#
# Pytorch implementation of the Trans paper "Few-Shot Learning for Domain-Specific Fine-Grained Image Classification"

# %%
# !python test_pw.py --support_num=1
# Out:
# ==> Reading from model checkpoint..
# [[93 30]
#  [ 3 66]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.76      0.85       123
#            1       0.69      0.96      0.80        69
#
#     accuracy                           0.83       192
#    macro avg       0.83      0.86      0.82       192
# weighted avg       0.87      0.83      0.83       192
#
# ...
# Figure(640x480)

# %% [markdown]
# ### Example [1-shot]
# ![image.png](attachment:image.png)

# %%
# !python test_pw.py --support_num=5
# Out:
# ==> Reading from model checkpoint..
# [[94 21]
#  [ 2 75]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.82      0.89       115
#            1       0.78      0.97      0.87        77
#
#     accuracy                           0.88       192
#    macro avg       0.88      0.90      0.88       192
# weighted avg       0.90      0.88      0.88       192
#
# ...
# Figure(640x480)

# %% [markdown]
# ### Example [5-shot]
# ![image.png](attachment:image.png)

# %%
# !python test_pw_.py --support_num=1
# Out:
# ==> Reading from model checkpoint..
# The random selected class is person.
# Figure(640x480)
# Attention torch.Size([10, 3, 84, 84])
# Attention2 torch.Size([10, 1024])
# The random selected class is wheelchair.
# Figure(640x480)
# Attention torch.Size([10, 3, 84, 84])
# Attention2 torch.Size([10, 1024])
# [[9 1]
#  [4 6]]
#               precision    recall  f1-score   support
#
#            0       0.69      0.90      0.78        10
#            1       0.86      0.60      0.71        10
#
#     accuracy                           0.75        20
#    macro avg       0.77      0.75      0.74        20
# weighted avg       0.77      0.75      0.74        20
#
# ...
# Figure(640x480)
#     Image_path      Actual  Prediction  isCorrect
# 0   3549_1.png      person      person    correct
# 1   5320_1.png      person      person    correct
# 2   5594_1.png      person      person    correct
# 3   2002_1.png      person      person    correct
# 4   2110_1.png      person      person    correct
# ...

# %% [markdown]
# ### Query set
# #### 001.Person
# ![image.png](attachment:image.png)
#
# #### 002.Wheelchair
# ![image-2.png](attachment:image-2.png)
#
# ##### Confusion Matrix Plot
# ![image-3.png](attachment:image-3.png)

# %%
# !python test_pw_.py --support_num=5
# Out:
# ==> Reading from model checkpoint..
# The random selected class is person.
# Figure(640x480)
# Attention torch.Size([10, 3, 84, 84])
# Attention2 torch.Size([10, 1024])
# The random selected class is wheelchair.
# Figure(640x480)
# Attention torch.Size([10, 3, 84, 84])
# Attention2 torch.Size([10, 1024])
# [[10  0]
#  [ 2  8]]
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        10
#            1       1.00      0.80      0.89        10
#
#     accuracy                           0.90        20
#    macro avg       0.92      0.90      0.90        20
# weighted avg       0.92      0.90      0.90        20
#
# ...
# Figure(640x480)
#     Image_path      Actual  Prediction  isCorrect
# 0   4072_1.png      person      person    correct
# 1   6331_2.png      person      person    correct
# 2   6401_2.png      person      person    correct
# 3   3889_2.png      person      person    correct
# ...

# %% [markdown]
# ### Query set
# #### 001.Person
# ![image.png](attachment:image.png)
#
# #### 002.Wheelchair
# ![image-2.png](attachment:image-2.png)
#
# ##### Confusion Matrix Plot
# ![image-3.png](attachment:image-3.png)
